# %% [markdown]
# <a href="https://colab.research.google.com/github/yoonjong8739/NLP_study/blob/master/_9_%ED%95%A9%EC%84%B1%EA%B3%B1_%EC%8B%A0%EA%B2%BD%EB%A7%9D(Convolution_Neural_Network).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 합성곱 신경망(Convolution Neural Network)
#
# - 이미지 인식, 음성 인식 등에 자주 사용되는데,
#   특히, 이미지 인식 분야에서 거의 모든 딥러닝 기술에 사용
#
# <br>
#
# ## 컨볼루션 신경망의 등장
# - 1989년 얀 르쿤(Yann LeCun) 교수의 논문에서 발표
#
#   - 필기체 인식에서 의미가 있었지만 범용화하는데에는 무리
#
# - 1998년, "Gradient-Based Learning Applied to Document Recognition"이라는 논문에서 LeNet-5 제시
#
# - 합성곱 층(convolution layer), 풀링 층(pooling layer) 소개
#   <br>
#
#   <img src="https://miro.medium.com/max/4308/1*1TI1aGBZ4dybR6__DI9dzA.png">
#
#   <center>[LeNet-5 구조]</center>
#
#   <sub>출처: https://medium.com/@pechyonkin/key-deep-learning-architectures-lenet-5-6fc3c59e6f4</sub>

# %% [markdown]
# ## 컨볼루션 신경망 구조 예시
#
# <img src="https://www.oreilly.com/api/v2/epubs/9781789138900/files/assets/c38754ca-f2ea-425a-b7a6-1fe0f2f5074e.png" width="600">
#
# <sub>출처: https://www.oreilly.com/library/view/neural-network-projects/9781789138900/8e87ad66-6de3-4275-81a4-62b54436bf16.xhtml</sub>

# %% [markdown]
# ## 합성곱 연산
# - 필터(filter) 연산
#   - 입력 데이터에 필터를 통한 어떠한 연산을 진행
#
#   - **필터에 대응하는 원소끼리 곱하고, 그 합을 구함**
#
#   - 연산이 완료된 결과 데이터를 **특징 맵(feature map)**이라 부름
#
# - 필터(filter)
#   - 커널(kernel)이라고도 칭함
#
#   - 흔히 사진 어플에서 사용하는 '이미지 필터'와 비슷한 개념
#
#   - 필터의 사이즈는 "거의 항상 홀수"
#     - 짝수이면 패딩이 비대칭이 되어버림
#
#     - 왼쪽, 오른쪽을 다르게 주어야함
#
#     - 중심위치가 존재, 즉 구별된 하나의 픽셀(중심 픽셀)이 존재
#
#   - 필터의 학습 파라미터 개수는 입력 데이터의 크기와 상관없이 일정
#     따라서, 과적합을 방지할 수 있음
#
#   <br>
#   <img src="https://www.tomasbeuzen.com/deep-learning-with-pytorch/_images/conv-1.gif">
#
#   <sub>출처: http://deeplearning.net/software/theano_versions/dev/tutorial/conv_arithmetic.html</sub>
#
#
# - 연산 시각화
#   <img src="https://www.researchgate.net/profile/Ihab_S_Mohamed/publication/324165524/figure/fig3/AS:611103423860736@1522709818959/An-example-of-convolution-operation-in-2D-2.png" width="500">
#
#   <sub>출처: https://www.researchgate.net/figure/An-example-of-convolution-operation-in-2D-2_fig3_324165524</sub>
#
#
# - 일반적으로, 합성곱 연산을 한 후의 데이터 사이즈는
#   ### $\quad (n-f+1) \times (n-f+1)$
#     $n$: 입력 데이터의 크기
#     $f$: 필터(커널)의 크기
#
#
#   <img src="https://miro.medium.com/max/1400/1*Fw-ehcNBR9byHtho-Rxbtw.gif" width="400">
#
#   <sub>출처: https://towardsdatascience.com/intuitively-understanding-convolutions-for-deep-learning-1f6f42faee1</sub>
#
#   위 예에서 입력 데이터 크기($n$)는 5, 필터의 크기($k$)는 3이므로
#   출력 데이터의 크기는 $(5 - 3 + 1) = 3$

# %% [markdown]
# ## 패딩(padding)과 스트라이드(stride)
# - 필터(커널) 사이즈과 함께 **입력 이미지와 출력 이미지의 사이즈를 결정**하기 위해 사용
#
# - 사용자가 결정할 수 있음

# %% [markdown]
# ### 패딩
# - 입력 데이터의 주변을 특정 값으로 채우는 기법
#   - 주로 0으로 많이 채움
#
#   <img src="http://deeplearning.net/software/theano_versions/dev/_images/arbitrary_padding_no_strides.gif" width="300">
#
# - 출력 데이터의 크기
#   ### $\quad (n+2p-f+1) \times (n+2p-f+1)$
#
#   위 그림에서, 입력 데이터의 크기($n$)는 5, 필터의 크기($f$)는 4, 패딩값($p$)은 2이므로
#   출력 데이터의 크기는 ($5 + 2\times 2 - 4 + 1) = 6$
#
# ### 'valid' 와 'same'
# - 'valid'
#   - 패딩을 주지 않음
#   - padding=0 (0으로 채워진 테두리가 아니라 패딩을 주지 않는다는 의미)
#
# - 'same'
#   - 패딩을 주어 입력 이미지의 크기와 연산 후의 이미지 크기를 같게함
#
#   - 만약, 필터(커널)의 크기가 $k$ 이면,
#     패딩의 크기는 $p = \frac{k-1}{2}$ (단, <u>stride=1)</u>

# %% [markdown]
# ### 스트라이드
# - 필터를 적용하는 간격을 의미
#
# - 아래는 그림의 간격 2
#
#   <img src="https://miro.medium.com/v2/resize:fit:588/1*BMngs93_rm2_BpJFH2mS0Q.gif">

# %% [markdown]
# ## 출력 데이터의 크기
#
# ## $\qquad OH = \frac{H + 2P - FH}{S} + 1 $
# ## $\qquad OW = \frac{W + 2P - FW}{S} + 1 $
#
# - 입력 크기 : $(H, W)$
#
# - 필터 크기 : $(FH, FW)$
#
# - 출력 크기 : $(OH, OW)$
#
# - 패딩, 스트라이드 : $P, S$
#
# - (주의)
#   - 위 식의 값에서 $\frac{H + 2P - FH}{S}$ 또는 $\frac{W + 2P - FW}{S}$가 정수로 나누어 떨어지는 값이어야 함
#   - 만약, 정수로 나누어 떨어지지 않으면
#     패딩, 스트라이드값을 조정하여 정수로 나누어 떨어지게 해야함

# %% [markdown]
# ## 풀링(Pooling)
#
# - 필터(커널) 사이즈 내에서 특정 값을 추출하는 과정

# %% [markdown]
# ### 맥스 풀링(Max Pooling)
# - 가장 많이 사용되는 방법
#
# - 출력 데이터의 사이즈 계산은 컨볼루션 연산과 동일
# ## $\quad OH = \frac{H + 2P - FH}{S} + 1 $
# ## $\quad OW = \frac{W + 2P - FW}{S} + 1 $
#
# - 일반적으로 stride=2, kernel_size=2 를 통해
#   **특징맵의 크기를 <u>절반으로 줄이는 역할</u>**
#
# - 모델이 물체의 주요한 특징을 학습할 수 있도록 해주며,
#   컨볼루션 신경망이 이동 불변성 특성을 가지게 해줌
#   - 예를 들어, 아래의 그림에서 초록색 사각형 안에 있는
#     2와 8의 위치를 바꾼다해도 맥스 풀링 연산은 8을 추출
#
# - 모델의 파라미터 개수를 줄여주고, 연산 속도를 빠르게 해줌
#
#   <br>
#
#   <img src="https://cs231n.github.io/assets/cnn/maxpool.jpeg" width="600">
#
#   <sub>출처: https://cs231n.github.io/convolutional-networks/</sub>

# %% [markdown]
# ## Conv1D
#
# - 텍스트 분류나 시계열 예측 같은 간단한 문제, 오디오 생성, 기계 번역 등의 문제에서 좋은 성능
#
# - 타임스텝의 순서에 민감하지 X
#
#
# - 2D Convolution
#   - 지역적 특징을 인식
#
#   <img src="https://jiho-ml.com/content/images/2020/07/2D-convolutional-example_2x-700x584.png" width="500">
#
# - 1D Convolution
#   - 문맥을 인식
#
#   <img src="https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FF2bI1%2FbtqJSciC5nJ%2FstSwF20OKLLuCSzvVz68fk%2Fimg.png" width="500">
#
#   <sub>출처: https://missinglink.ai/guides/keras/keras-conv1d-working-1d-convolutional-neural-networks-keras/</sub>

# %% [markdown]
# ### Conv1D Layer
# - 입력: `(batch_size, timesteps, channels)`
#
# - 출력: `(batch_size, timesteps, filters)`
#
# - 필터의 사이즈가 커져도 모델이 급격히 증가하지 않기 때문에 다양한 크기를 사용할 수 있음
# - 데이터의 품질이 좋으면 굳이 크기를 달리하여 여러 개를 사용하지 않아도 될 수도 있음

# %% [markdown]
# ### MaxPooling1D Layer
# - 다운 샘플링 효과
#
# - 단지 1차원형태로 바뀐 것 뿐

# %% [markdown]
# ### GlobalMaxPooling Layer
# - 배치차원을 제외하고 2차원 형태를 1차원 형태로 바꾸어주는 레이어
#
# - Flatten layer로 대신 사용가능

# %% [markdown]
# ## IMDB 데이터

# %% [markdown]
# ### 데이터 로드 및 전처리

# %%
from keras.datasets import imdb
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.optimizers import RMSprop
from keras.layers import Dense, Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D

# %%
num_words = 10000
max_len = 500
batch_size = 32

(input_train, y_train), (input_test, y_test) = imdb.load_data(num_words = num_words)
print(len(input_train))
print(len(input_test))
# Out:
# 25000
# 25000

# %%
pad_x_train = pad_sequences(input_train, maxlen=max_len)
pad_x_test = pad_sequences(input_test, maxlen=max_len)

print(pad_x_train.shape)
print(pad_x_test.shape)
# Out:
# (25000, 500)
# (25000, 500)

# %% [markdown]
# ### 모델 구성

# %%
def build_model():
    model = Sequential()

    model.add(Embedding(input_dim=num_words, output_dim=32, input_length=max_len))

    model.add(Conv1D(filters=32, kernel_size=7, activation='relu'))
    model.add(MaxPooling1D(pool_size=7))
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu'))
    model.add(MaxPooling1D(pool_size=5))

    model.add(GlobalMaxPooling1D())  # Flatten()으로 대신 사용

    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer = RMSprop(learning_rate=1e-4),
                  loss = 'binary_crossentropy',
                  metrics = ['acc'])

    return model

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 500, 32)           320000
#
#  conv1d (Conv1D)             (None, 494, 32)           7200
#
#  max_pooling1d (MaxPooling1D  (None, 70, 32)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 66, 32)            5152
#
#  max_pooling1d_1 (MaxPooling  (None, 13, 32)           0
#  1D)
#
#  global_max_pooling1d (Globa  (None, 32)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 332,385
# Trainable params: 332,385
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 모델 학습

# %%
history = model.fit(
    pad_x_train, y_train,
    batch_size = 128, epochs = 30,
    validation_split = 0.2
)
# Out:
# Epoch 1/30
# 157/157 [==============================] - 5s 9ms/step - loss: 0.6929 - acc: 0.5152 - val_loss: 0.6923 - val_acc: 0.5166
# Epoch 2/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.6907 - acc: 0.5818 - val_loss: 0.6914 - val_acc: 0.5880
# Epoch 3/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.6881 - acc: 0.6564 - val_loss: 0.6896 - val_acc: 0.5768
# Epoch 4/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.6836 - acc: 0.7186 - val_loss: 0.6835 - val_acc: 0.7180
# Epoch 5/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.6730 - acc: 0.7767 - val_loss: 0.6676 - val_acc: 0.7508
# Epoch 6/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.6461 - acc: 0.7969 - val_loss: 0.6274 - val_acc: 0.7866
# Epoch 7/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.5883 - acc: 0.8080 - val_loss: 0.5568 - val_acc: 0.8032
# Epoch 8/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.5053 - acc: 0.8274 - val_loss: 0.4752 - val_acc: 0.8196
# Epoch 9/30
# 157/157 [==============================] - 1s 8ms/step - loss: 0.4244 - acc: 0.8457 - val_loss: 0.4145 - val_acc: 0.8340
# Epoch 10/30
# 157/157 [==============================] - 1s 9ms/step - loss: 0.3658 - acc: 0.8589 - val_loss: 0.3791 - val_acc: 0.8374
# Epoch 11/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.3266 - acc: 0.8717 - val_loss: 0.3585 - val_acc: 0.8458
# Epoch 12/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.2993 - acc: 0.8820 - val_loss: 0.3459 - val_acc: 0.8500
# Epoch 13/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.2787 - acc: 0.8909 - val_loss: 0.3356 - val_acc: 0.8544
# Epoch 14/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.2617 - acc: 0.8963 - val_loss: 0.3306 - val_acc: 0.8562
# Epoch 15/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.2467 - acc: 0.9039 - val_loss: 0.3275 - val_acc: 0.8590
# Epoch 16/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.2341 - acc: 0.9105 - val_loss: 0.3293 - val_acc: 0.8590
# Epoch 17/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.2229 - acc: 0.9160 - val_loss: 0.3256 - val_acc: 0.8642
# Epoch 18/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.2124 - acc: 0.9219 - val_loss: 0.3251 - val_acc: 0.8638
# Epoch 19/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.2027 - acc: 0.9255 - val_loss: 0.3258 - val_acc: 0.8642
# Epoch 20/30
# 157/157 [==============================] - 1s 9ms/step - loss: 0.1936 - acc: 0.9303 - val_loss: 0.3278 - val_acc: 0.8660
# Epoch 21/30
# 157/157 [==============================] - 1s 9ms/step - loss: 0.1852 - acc: 0.9342 - val_loss: 0.3303 - val_acc: 0.8662
# Epoch 22/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.1776 - acc: 0.9377 - val_loss: 0.3324 - val_acc: 0.8648
# Epoch 23/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.1700 - acc: 0.9406 - val_loss: 0.3353 - val_acc: 0.8648
# Epoch 24/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.1632 - acc: 0.9435 - val_loss: 0.3399 - val_acc: 0.8630
# Epoch 25/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.1569 - acc: 0.9466 - val_loss: 0.3458 - val_acc: 0.8624
# Epoch 26/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.1511 - acc: 0.9486 - val_loss: 0.3474 - val_acc: 0.8636
# Epoch 27/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.1452 - acc: 0.9508 - val_loss: 0.3579 - val_acc: 0.8626
# Epoch 28/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.1397 - acc: 0.9534 - val_loss: 0.3578 - val_acc: 0.8592
# Epoch 29/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.1345 - acc: 0.9549 - val_loss: 0.3636 - val_acc: 0.8610
# Epoch 30/30
# 157/157 [==============================] - 1s 7ms/step - loss: 0.1294 - acc: 0.9575 - val_loss: 0.3672 - val_acc: 0.8612

# %% [markdown]
# ### 시각화

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['acc']
val_acc = history.history['val_acc']

epochs = range(1, len(loss)+1)

plt.figure(figsize=(12,8))
plt.subplot(1,2,1)
plt.plot(epochs, loss, 'r--', label='train loss')
plt.plot(epochs, val_loss, 'b:', label='validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('train loss vs validation loss')
plt.legend()
plt.grid(True)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'r--', label='train accuracy')
plt.plot(epochs, val_acc, 'b:', label='validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('train accuracy vs validation accuracy')
plt.legend()
plt.grid(True)

plt.show();

# %%
model.evaluate(pad_x_test, y_test)
# Out:
# 782/782 [==============================] - 2s 3ms/step - loss: 0.3895 - acc: 0.8472
# [0.3895144462585449, 0.8471999764442444]

# %% [markdown]
# ## Reuters 데이터

# %% [markdown]
# ### 데이터 로드 및 전처리

# %%
from keras.datasets import reuters

# %%
num_words = 10000
max_len = 500
batch_size = 32

(input_train, y_train), (input_test, y_test) = reuters.load_data(num_words = num_words)

print(len(input_train))
print(len(input_test))
# Out:
# 8982
# 2246

# %%
pad_x_train = pad_sequences(input_train, maxlen=max_len)
pad_x_test = pad_sequences(input_test, maxlen=max_len)

print(pad_x_train.shape)
print(pad_x_test.shape)
# Out:
# (8982, 500)
# (2246, 500)

# %% [markdown]
# ### 모델 구성

# %%
def build_model2():
    model = Sequential()

    model.add(Embedding(input_dim=num_words, output_dim=64, input_length=max_len))

    model.add(Conv1D(filters=64, kernel_size=7, activation='relu'))
    model.add(MaxPooling1D(pool_size=7))
    model.add(Conv1D(filters=64, kernel_size=5, activation='relu'))
    model.add(MaxPooling1D(pool_size=5))

    model.add(GlobalMaxPooling1D())  # Flatten()으로 대신 사용

    model.add(Dense(46, activation='softmax'))

    model.compile(optimizer = 'adam',
                  loss = 'sparse_categorical_crossentropy',
                  metrics = ['acc'])

    return model

# %%
model = build_model2()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 500, 64)           640000
#
#  conv1d_2 (Conv1D)           (None, 494, 64)           28736
#
#  max_pooling1d_2 (MaxPooling  (None, 70, 64)           0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 66, 64)            20544
#
#  max_pooling1d_3 (MaxPooling  (None, 13, 64)           0
#  1D)
#
#  global_max_pooling1d_1 (Glo  (None, 64)               0
#  balMaxPooling1D)
#
#  dense_1 (Dense)             (None, 46)                2990
#
# =================================================================
# Total params: 692,270
# Trainable params: 692,270
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 모델 학습

# %%
history2 = model.fit(
    pad_x_train, y_train,
    batch_size = 128, epochs = 30,
    validation_split = 0.2
)
# Out:
# Epoch 1/30
# 57/57 [==============================] - 16s 252ms/step - loss: 2.6841 - acc: 0.3663 - val_loss: 2.0261 - val_acc: 0.4975
# Epoch 2/30
# 57/57 [==============================] - 12s 207ms/step - loss: 1.8510 - acc: 0.5243 - val_loss: 1.7103 - val_acc: 0.5409
# Epoch 3/30
# 57/57 [==============================] - 12s 204ms/step - loss: 1.6011 - acc: 0.5873 - val_loss: 1.5662 - val_acc: 0.6227
# Epoch 4/30
# 57/57 [==============================] - 9s 159ms/step - loss: 1.4075 - acc: 0.6586 - val_loss: 1.4360 - val_acc: 0.6578
# Epoch 5/30
# 57/57 [==============================] - 9s 154ms/step - loss: 1.1940 - acc: 0.7129 - val_loss: 1.3272 - val_acc: 0.6939
# Epoch 6/30
# 57/57 [==============================] - 7s 134ms/step - loss: 0.9878 - acc: 0.7552 - val_loss: 1.2658 - val_acc: 0.7117
# Epoch 7/30
# 57/57 [==============================] - 8s 146ms/step - loss: 0.8082 - acc: 0.7916 - val_loss: 1.2309 - val_acc: 0.7268
# Epoch 8/30
# 57/57 [==============================] - 9s 157ms/step - loss: 0.6615 - acc: 0.8308 - val_loss: 1.2617 - val_acc: 0.7340
# Epoch 9/30
# 57/57 [==============================] - 5s 84ms/step - loss: 0.5384 - acc: 0.8657 - val_loss: 1.3028 - val_acc: 0.7340
# Epoch 10/30
# 57/57 [==============================] - 8s 142ms/step - loss: 0.4440 - acc: 0.8913 - val_loss: 1.3789 - val_acc: 0.7340
# Epoch 11/30
# 57/57 [==============================] - 7s 122ms/step - loss: 0.3592 - acc: 0.9134 - val_loss: 1.4408 - val_acc: 0.7290
# Epoch 12/30
# 57/57 [==============================] - 6s 103ms/step - loss: 0.3022 - acc: 0.9296 - val_loss: 1.4707 - val_acc: 0.7390
# Epoch 13/30
# 57/57 [==============================] - 5s 92ms/step - loss: 0.2525 - acc: 0.9424 - val_loss: 1.5267 - val_acc: 0.7368
# Epoch 14/30
# 57/57 [==============================] - 5s 93ms/step - loss: 0.2153 - acc: 0.9505 - val_loss: 1.6236 - val_acc: 0.7301
# Epoch 15/30
# 57/57 [==============================] - 4s 68ms/step - loss: 0.1937 - acc: 0.9574 - val_loss: 1.6123 - val_acc: 0.7284
# Epoch 16/30
# 57/57 [==============================] - 4s 72ms/step - loss: 0.1790 - acc: 0.9569 - val_loss: 1.6542 - val_acc: 0.7340
# Epoch 17/30
# 57/57 [==============================] - 4s 73ms/step - loss: 0.1625 - acc: 0.9585 - val_loss: 1.6934 - val_acc: 0.7329
# Epoch 18/30
# 57/57 [==============================] - 4s 68ms/step - loss: 0.1424 - acc: 0.9621 - val_loss: 1.7649 - val_acc: 0.7279
# Epoch 19/30
# 57/57 [==============================] - 4s 71ms/step - loss: 0.1527 - acc: 0.9594 - val_loss: 1.7466 - val_acc: 0.7346
# Epoch 20/30
# 57/57 [==============================] - 3s 55ms/step - loss: 0.1426 - acc: 0.9630 - val_loss: 1.6881 - val_acc: 0.7407
# Epoch 21/30
# 57/57 [==============================] - 2s 39ms/step - loss: 0.1311 - acc: 0.9658 - val_loss: 1.7104 - val_acc: 0.7401
# Epoch 22/30
# 57/57 [==============================] - 4s 75ms/step - loss: 0.1247 - acc: 0.9617 - val_loss: 1.7345 - val_acc: 0.7396
# Epoch 23/30
# 57/57 [==============================] - 3s 55ms/step - loss: 0.1193 - acc: 0.9656 - val_loss: 1.7539 - val_acc: 0.7368
# Epoch 24/30
# 57/57 [==============================] - 3s 46ms/step - loss: 0.1209 - acc: 0.9646 - val_loss: 1.7453 - val_acc: 0.7307
# Epoch 25/30
# 57/57 [==============================] - 2s 36ms/step - loss: 0.1147 - acc: 0.9646 - val_loss: 1.7147 - val_acc: 0.7457
# Epoch 26/30
# 57/57 [==============================] - 2s 42ms/step - loss: 0.1096 - acc: 0.9640 - val_loss: 1.7488 - val_acc: 0.7279
# Epoch 27/30
# 57/57 [==============================] - 2s 31ms/step - loss: 0.1038 - acc: 0.9665 - val_loss: 1.7891 - val_acc: 0.7362
# Epoch 28/30
# 57/57 [==============================] - 3s 50ms/step - loss: 0.1114 - acc: 0.9642 - val_loss: 1.7474 - val_acc: 0.7423
# Epoch 29/30
# 57/57 [==============================] - 2s 36ms/step - loss: 0.1040 - acc: 0.9641 - val_loss: 1.7896 - val_acc: 0.7385
# Epoch 30/30
# 57/57 [==============================] - 1s 18ms/step - loss: 0.1061 - acc: 0.9634 - val_loss: 1.7326 - val_acc: 0.7368

# %% [markdown]
# ### 시각화

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

loss = history2.history['loss']
val_loss = history2.history['val_loss']
acc = history2.history['acc']
val_acc = history2.history['val_acc']

epochs = range(1, len(loss)+1)

plt.figure(figsize=(12,8))
plt.subplot(1,2,1)
plt.plot(epochs, loss, 'r--', label='train loss')
plt.plot(epochs, val_loss, 'b:', label='validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('train loss vs validation loss')
plt.legend()
plt.grid(True)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'r--', label='train accuracy')
plt.plot(epochs, val_acc, 'b:', label='validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('train accuracy vs validation accuracy')
plt.legend()
plt.grid(True)

plt.show();

# %%
model.evaluate(pad_x_test, y_test)
# Out:
# 71/71 [==============================] - 1s 9ms/step - loss: 1.6510 - acc: 0.7400
# [1.6510415077209473, 0.7399821877479553]
